# %% [markdown]
# # Files

# %%
# !pwd
# Out:
# /home/dvd/Desktop/LearnPython

# %%
import glob
print(glob.glob('data/inflammation*.csv'))
# Out:
# ['data/inflammation-03.csv', 'data/inflammation-12.csv', 'data/inflammation-11.csv', 'data/inflammation-06.csv', 'data/inflammation-07.csv', 'data/inflammation-09.csv', 'data/inflammation-05.csv', 'data/inflammation-01.csv', 'data/inflammation-08.csv', 'data/inflammation-04.csv', 'data/inflammation-10.csv', 'data/inflammation-02.csv']

# %%
filenames = sorted(glob.glob('data/inflammation*csv'))

# %%
print(filenames)
# Out:
# ['data/inflammation-01.csv', 'data/inflammation-02.csv', 'data/inflammation-03.csv', 'data/inflammation-04.csv', 'data/inflammation-05.csv', 'data/inflammation-06.csv', 'data/inflammation-07.csv', 'data/inflammation-08.csv', 'data/inflammation-09.csv', 'data/inflammation-10.csv', 'data/inflammation-11.csv', 'data/inflammation-12.csv']

# %%
# %matplotlib inline
import matplotlib.pyplot
import numpy

# %%
for file_i in filenames:
    print(file_i)
    data = numpy.loadtxt(fname=file_i, delimiter=',')
    
    fig = matplotlib.pyplot.figure(figsize=(10, 3))

    axes1 = fig.add_subplot(1, 3, 1)
    axes1.set_ylabel('average')
    axes1.plot(data.mean(axis=0))

    axes2 = fig.add_subplot(1, 3, 2)
    axes2.set_ylabel('max')
    axes2.plot(data.max(axis=0))

    axes3 = fig.add_subplot(1, 3, 3)
    axes3.set_ylabel('min')
    axes3.set_ylim(0,6)
    axes3.plot(data.min(axis=0))

    fig.tight_layout()
    matplotlib.pyplot.show()
# Out:
# data/inflammation-01.csv
# data/inflammation-02.csv
# data/inflammation-03.csv
# data/inflammation-04.csv
# data/inflammation-05.csv
# data/inflammation-06.csv
# data/inflammation-07.csv
# data/inflammation-08.csv
# data/inflammation-09.csv
# data/inflammation-10.csv
# data/inflammation-11.csv
# data/inflammation-12.csv
